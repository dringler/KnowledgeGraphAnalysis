# %%
# get all classes ("concept:")
import os
import time
import string
import itertools
import re

start = time.time()

ontologySample = 'NELL/NELL_ontology_sample.csv'
ontology = 'NELL/NELL.08m.995.ontology.csv'

# CHANGE HERE FOR FULL ONTOLOGY
readOntology = ontologySample
#readOntology = ontology

conceptArray = []

lineCounter = 0
lineProgress = 100000
#maxLines = 1000000

try:
    # read ontology
    fr = open(readOntology, 'r')
    
    for line in fr:
        splitted_line = line.rstrip('\n').split('\t') #remove line break in the end, split line on tab
        #position_counter = 0
        #print splitted_line
        for word in splitted_line:
#### concept:book	memberofsets	concept:rtwcategory: check for rtwcategory?            
            if word.startswith('concept:'): # check for concepts
                if not word in conceptArray:
                    conceptArray.append(word)
        lineCounter += 1
        if (lineCounter % lineProgress == 0):
            print ('{} lines read'.format(lineCounter))
    print conceptArray
    fr.close()
    print ('FINISHED')
except:
    print ('ERROR')
    
end = time.time()        
print ('EXECUTION TIME: {} s'.format(end-start))
# Out:
# ['concept:everypromotedthing', 'concept:rtwcategory', 'concept:geolocatablething', 'concept:academicfield', 'concept:awardtrophytournament', 'concept:buildingmaterial', 'concept:celltype', 'concept:charactertrait', 'concept:chemical', 'concept:cognitiveactions', 'concept:currency', 'concept:date', 'concept:economicsector', 'concept:emotion', 'concept:ethnicgroup', 'concept:event', 'concept:geometricshape', 'concept:hobby', 'concept:medicalprocedure', 'concept:mlalgorithm', 'concept:mlarea', 'concept:mldataset', 'concept:mlmetric', 'concept:musicgenre', 'concept:perceptionaction', 'concept:perceptionevent', 'concept:physicalaction', 'concept:physicalcharacteristic', 'concept:physicsterm', 'concept:profession', 'concept:protein', 'concept:religion', 'concept:sociopolitical', 'concept:sport', 'concept:visualartmovement', 'concept:politicaloffice', 'concept:color', 'concept:language', 'concept:species', 'concept:programminglanguage', 'concept:gamescore', 'concept:nonneginteger', 'concept:politicsissue', 'concept:llcoordinate', 'concept:recipe', 'concept:game', 'concept:researchproject', 'concept:creativework', 'concept:politicsbill', 'concept:physiologicalcondition', 'concept:sportsteamposition', 'concept:animal', 'concept:person', 'concept:item', 'concept:visualizableattribute', 'concept:visualizableobject', 'concept:scientificterm', 'concept:time', 'concept:victim', 'concept:oilgasfield', 'concept:visualizablescene', 'concept:city']
# FINISHED
# EXECUTION TIME: 0.00136709213257 s

# %%
# check how many entities have the "categories for entity" attribute
import os
import time
import string
import itertools
import re
import operator

start = time.time()

nellSample = 'NELL/NELL_sample.csv'
nell = 'NELL/NELL.08m.995.esv.csv'
readNell = nell


countCat = {} #key: value, value: count
countCat['hasCat'] = 0
countCat['noCat'] = 0

hasCat = set()
seenEntities = set()

lineCounter = 0
lineProgress = 500000

def checkWords(splittedLine):
    word_position = 0
    #newEntity = False
    for word in splitted_line:
        if (word_position==0): #Entity
            entity = word
        if (word_position==10): # categories for entity
            categories = word
            if entity in seenEntities:
                return
            else:
                seenEntities.add(entity)
                if (categories == ''):
                    countCat['noCat'] += 1
                    return
                else:
                    countCat['hasCat'] += 1
                    hasCat.add(entity)
                    #print ('empty cat')
                    return # break function
        word_position += 1
    

print('START')
try:
    # read nell
    fn = open(readNell, 'r')
    for line in fn:
        if (lineCounter != 0):
            splitted_line = line.rstrip('\n').split('\t')
            checkWords(splitted_line)
        lineCounter += 1
        if (lineCounter % lineProgress == 0):
            print ('{} lines read'.format(lineCounter))
    print countCat
    print ('len(hasCat): {}'.format(len(hasCat)))
    fn.close()
    print ('DONE')
except:
    print('ERROR')

end = time.time()
print ('EXECUTION TIME: {} s'.format(end-start))
# Out:
# START
# 500000 lines read
# 1000000 lines read
# 1500000 lines read
# 2000000 lines read
# 2500000 lines read
# {'hasCat': 1974586, 'noCat': 167399}
# len(hasCat): 1974586
# DONE
# EXECUTION TIME: 21.2120959759 s

# %%
# check how many entities have the "generalizations" relation & 
# check if they are the same that have the categories for entity attribute
import os
import time
import string
import itertools
import re
import operator

start = time.time()

nellSample = 'NELL/NELL_sample.csv'
nell = 'NELL/NELL.08m.995.esv.csv'
readNell = nell


countCat = {} #key: value, value: count
countCat['hasGenRel'] = 0
countCat['noGenRel'] = 0

allEntities = set()
hasGeneralization = set()

lineCounter = 0
lineProgress = 500000

def checkWords(splittedLine):
    word_position = 0
    #newEntity = False
    for word in splitted_line:
        if (word_position==0): #Entity
            entity = word
            if entity not in allEntities:
                # add to list of all entities
                allEntities.add(entity)                
        if (word_position==1): #relation
            relation = word
            if (relation == "generalizations"):
                hasGeneralization.add(entity)
            else:
                return
        word_position += 1
    

print('START')
try:
    # read nell
    fn = open(readNell, 'r')
    for line in fn:
        if (lineCounter != 0):
            splitted_line = line.rstrip('\n').split('\t')
            checkWords(splitted_line)
        lineCounter += 1
        if (lineCounter % lineProgress == 0):
            print ('{} lines read'.format(lineCounter))
    print ('len(allEntities): {}'.format(len(allEntities)))
    print ('len(hasGeneralization): {}'.format(len(hasGeneralization)))
    print ('len(hasCat): {}'.format(len(hasCat)))
    #find different items in both sets
    print('# of different items in hasGeneralization and hasCat: {}'.format(len(hasGeneralization-hasCat)))
    fn.close()
    print ('DONE')
except:
    print('ERROR')

end = time.time()
print ('EXECUTION TIME: {} s'.format(end-start))
# Out:
# START
# 500000 lines read
# 1000000 lines read
# 1500000 lines read
# 2000000 lines read
# 2500000 lines read
# len(allEntities): 2141985
# len(hasGeneralization): 1974586
# len(hasCat): 1974586
# # of different items in hasGeneralization and hasCat: 0
# DONE
# EXECUTION TIME: 21.9871029854 s

# %%
# "generalizations"-relation attribute
import os
import time
import string
import itertools
import re
import operator

start = time.time()

nellSample = 'NELL/NELL_sample.csv'
nell = 'NELL/NELL.08m.995.esv.csv'
readNell = nell

outputFile = 'NELL/generalization.txt'

#header of files: Entity	Relation	Value	Iteration of Promotion	Probability	Source	Entity literalStrings	Value literalStrings	Best Entity literalString	Best Value literalString	Categories for Entity	Categories for Value	Candidate Source

relationArray = []
genFoundArray = []
genValueCount = {} #key: value, value: count
seenEntities = set()

lineCounter = 0
lineProgress = 500000

print('START')
try:
    # read nell
    fn = open(readNell, 'r')
    for line in fn:
        genFound = False
        #nirvanaFound = False
        newEntity = False
        lineWords = []
        splitted_line = line.rstrip('\n').split('\t')
        word_position = 0
        catCandidate = ""
        for word in splitted_line:
            #lineWords.append(word)
            if (word_position==0): #Entity
                if word not in seenEntities:
                    seenEntities.add(word)
                    newEntity = True                    
            if (word_position==1): #relation
            #    if word not in relationArray:
            #        relationArray.append(word)
# get all values when the relation is 'generalizations
                if (word == "generalizations"):
                    genFound = True
            if (word_position==2 and genFound): #value
                catCandidate = word
###
# WITHOUT PROBABILITY
                if catCandidate not in genValueCount:
                    genValueCount[catCandidate] = 0
                else:
                    genValueCount[catCandidate] += 1
# END WITHOUT PROBABILITY
###
###
# WITH PROBABILITY                
#            if (word_position==4 and genFound): #Probability
#                prob = float(word)
#                if prob==1:
#                    if catCandidate not in genValueCount:
#                        genValueCount[catCandidate] = 0
#                    else:
#                        genValueCount[catCandidate] += 1
###
            word_position += 1
        #if(genFound):
        #    genFoundArray.append(lineWords)
        lineCounter += 1
        if (lineCounter % lineProgress == 0):
            print ('{} lines read'.format(lineCounter))
    #print relationArray
    #print genFoundArray
    # sorted list for generalization count
    print sorted(genValueCount.items(), key=operator.itemgetter(1), reverse=True)
    fn.close()
    print ('DONE')
except:
    print('ERROR')

end = time.time()
print ('EXECUTION TIME: {} s'.format(end-start))
# Out:
# START
# 500000 lines read
# 1000000 lines read
# 1500000 lines read
# 2000000 lines read
# 2500000 lines read
# [('concept:beach', 34501), ('concept:actor', 29293), ('concept:governmentorganization', 27738), ('concept:director', 27569), ('concept:skiarea', 27356), ('concept:street', 25287), ('concept:river', 23763), ('concept:airport', 23719), ('concept:celebrity', 23424), ('concept:male', 23277), ('concept:hospital', 22809), ('concept:chemical', 22149), ('concept:hotel', 22062), ('concept:radiostation', 21917), ('concept:mldataset', 21757), ('concept:drug', 21617), ('concept:personcanada', 21063), ('concept:bank', 20849), ('concept:bacteria', 20414), ('concept:professor', 20334), ('concept:athlete', 19649), ('concept:comedian', 19580), ('concept:writer', 19366), ('concept:disease', 19066), ('concept:city', 18670), ('concept:lake', 18587), ('concept:university', 18485), ('concept:personaustralia', 17949), ('concept:religion', 17896), ('concept:journalist', 17780), ('concept:trail', 17596), ('concept:coach', 17534), ('concept:museum', 17509), ('concept:website', 17194), ('concept:bird', 17136), ('concept:protein', 17117), ('concept:personeurope', 16915), ('concept:female', 16888), ('concept:politicianus', 16777), ('concept:automobilemodel', 16715), ('concept:biotechcompany', 16488), ('concept:highway', 16458), ('concept:visualartist', 16396), ('concept:personmexico', 16038), ('concept:archaea', 15742), ('concept:creditunion', 15733), ('concept:personasia', 15332), ('concept:chef', 15212), ('concept:personafrica', 15015), ('concept:park', 14852), ('concept:winery', 14800), ('concept:personus', 14003), ('concept:recipe', 13806), ('concept:videogame', 13684), ('concept:mlmetric', 13593), ('concept:newspaper', 13542), ('concept:county', 13410), ('concept:stadiumoreventvenue', 13327), ('concept:jobposition', 13250), ('concept:recordlabel', 13050), ('concept:musicsong', 12820), ('concept:language', 12735), ('concept:fish', 12490), ('concept:criminal', 12405), ('concept:televisionstation', 12308), ('concept:musicartist', 12293), ('concept:date', 12240), ('concept:architect', 12225), ('concept:clothing', 12124), ('concept:professionalorganization', 12055), ('concept:mlauthor', 11873), ('concept:filmfestival', 11735), ('concept:year', 11540), ('concept:sportsteam', 11357), ('concept:politicsbill', 10947), ('concept:medicalprocedure', 10876), ('concept:mlarea', 10800), ('concept:restaurant', 10776), ('concept:mammal', 10662), ('concept:insect', 10653), ('concept:physicalcharacteristic', 10565), ('concept:ceo', 10460), ('concept:musician', 10397), ('concept:model', 10356), ('concept:scientist', 10321), ('concept:mountain', 10153), ('concept:physicsterm', 10091), ('concept:bakedgood', 9983), ('concept:race', 9825), ('concept:parlourgame', 9766), ('concept:boardgame', 9723), ('concept:reptile', 9618), ('concept:amphibian', 9489), ('concept:shoppingmall', 9465), ('concept:musicfestival', 9340), ('concept:academicfield', 9260), ('concept:politician', 9137), ('concept:militaryconflict', 9037), ('concept:politicsblog', 9026), ('concept:politicalparty', 8887), ('concept:profession', 8805), ('concept:book', 8517), ('concept:mollusk', 8455), ('concept:charactertrait', 8260), ('concept:port', 8256), ('concept:tool', 7989), ('concept:personnorthamerica', 7942), ('concept:transportation', 7857), ('concept:magazine', 7750), ('concept:cardgame', 7733), ('concept:physiologicalcondition', 7730), ('concept:condiment', 7613), ('concept:tableitem', 7597), ('concept:retailstore', 7558), ('concept:bedroomitem', 7479), ('concept:monument', 7479), ('concept:astronaut', 7465), ('concept:mlalgorithm', 7269), ('concept:product', 7050), ('concept:plant', 6957), ('concept:cognitiveactions', 6877), ('concept:furniture', 6872), ('concept:placeofworship', 6852), ('concept:automobilemaker', 6707), ('concept:trainstation', 6645), ('concept:blog', 6639), ('concept:movie', 6626), ('concept:consumerelectronicitem', 6308), ('concept:farm', 6159), ('concept:ethnicgroup', 6143), ('concept:company', 6131), ('concept:vehicle', 6114), ('concept:island', 6100), ('concept:awardtrophytourname ...
# DONE
# EXECUTION TIME: 25.9346239567 s

# %%
# categories for entity testing
import os
import time
import string
import itertools
import re
import operator

start = time.time()

nellSample = 'NELL/NELL_sample.csv'
nell = 'NELL/NELL.08m.995.esv.csv'
readNell = nell

#outputFile = 'NELL/generalization.txt'

#header of files: Entity	Relation	Value	Iteration of Promotion	Probability	Source	Entity literalStrings	Value literalStrings	Best Entity literalString	Best Value literalString	Categories for Entity	Categories for Value	Candidate Source


categoryCount = {} #key: category, value: count
genValueCount = {} #key: value, value: count
seenEntities = set()

lineCounter = 0
lineProgress = 1000000

def checkWords(splittedLine):
    word_position = 0
    #newEntity = False
    for word in splitted_line:
        if (word_position==0): #Entity
            entity = word
        if (word_position==4): #Probability
            prob = float(word)
            if (prob < 1):
                return
        if (word_position==10): # categories for entity
            categories = word
            if (categories == ''):
                #print ('empty cat')
                return # break function
            else:
                if entity in seenEntities:
                    #print('seen: {}'.format(entity))
                    return #break function
                else:
                    #print('not seen: {}'.format(entity))
                    seenEntities.add(entity)
                    for category in categories.split(): #split on whitespace for multiple categories
                        if category not in categoryCount:
                            categoryCount[category] = 0
                        else:
                            categoryCount[category] += 1
#        if (word_position==4): #Probability
#            prob = float(word)
#            if prob==1:
#                if catCandidate not in genValueCount:
#                    genValueCount[catCandidate] = 0
#                else:
#                    genValueCount[catCandidate] += 1
        word_position += 1
    

print('START')
try:
    # read nell
    fn = open(readNell, 'r')
    for line in fn:
        if (lineCounter != 0):
            splitted_line = line.rstrip('\n').split('\t')
            checkWords(splitted_line)
        lineCounter += 1
        if (lineCounter % lineProgress == 0):
            print ('{} lines read'.format(lineCounter))
            #print sorted(categoryCount.items(), key=operator.itemgetter(1), reverse=True)
    print sorted(categoryCount.items(), key=operator.itemgetter(1), reverse=True)
    fn.close()
    print ('DONE')
except:
    print('ERROR')

end = time.time()
print ('EXECUTION TIME: {} s'.format(end-start))
# Out:
# START
# 500000 lines read
# 1000000 lines read
# 1500000 lines read
# 2000000 lines read
# 2500000 lines read
# [('concept:athlete', 2312), ('concept:product', 2052), ('concept:male', 2031), ('concept:person', 2000), ('concept:county', 1985), ('concept:bird', 1858), ('concept:celebrity', 1573), ('concept:coach', 1571), ('concept:actor', 1534), ('concept:airport', 1499), ('concept:chemical', 1480), ('concept:city', 1456), ('concept:hotel', 1416), ('concept:website', 1349), ('concept:lake', 1315), ('concept:creditunion', 1237), ('concept:personeurope', 1221), ('concept:hospital', 1215), ('concept:sportsteam', 1205), ('concept:university', 1195), ('concept:personmexico', 1150), ('concept:skiarea', 1141), ('concept:bank', 1025), ('concept:televisionstation', 1009), ('concept:comedian', 994), ('concept:drug', 987), ('concept:trail', 985), ('concept:politicianus', 979), ('concept:clothing', 945), ('concept:filmfestival', 936), ('concept:magazine', 906), ('concept:river', 900), ('concept:female', 879), ('concept:museum', 851), ('concept:professor', 831), ('concept:personcanada', 799), ('concept:automobilemodel', 792), ('concept:personasia', 790), ('concept:bakedgood', 787), ('concept:park', 773), ('concept:biotechcompany', 757), ('concept:disease', 742), ('concept:personafrica', 739), ('concept:newspaper', 722), ('concept:everypromotedthing', 692), ('concept:port', 682), ('concept:profession', 676), ('concept:writer', 673), ('concept:traditionalgame', 650), ('concept:personaustralia', 637), ('concept:personus', 622), ('concept:transportation', 606), ('concept:company', 597), ('concept:date', 580), ('concept:journalist', 565), ('concept:jobposition', 525), ('concept:vertebrate', 521), ('concept:mammal', 519), ('concept:stadiumoreventvenue', 517), ('concept:politicsbill', 515), ('concept:director', 511), ('concept:bacteria', 510), ('concept:food', 502), ('concept:geopoliticallocation', 496), ('concept:mountain', 457), ('concept:protein', 455), ('concept:ceo', 454), ('concept:movie', 446), ('concept:stateorprovince', 445), ('concept:zoo', 427), ('concept:insect', 415), ('concept:religion', 413), ('concept:scientist', 391), ('concept:attraction', 390), ('concept:aquarium', 390), ('concept:condiment', 387), ('concept:perceptionaction', 382), ('concept:visualizablething', 378), ('concept:visualizablescene', 376), ('concept:archaea', 372), ('concept:mollusk', 368), ('concept:visualizableobject', 359), ('concept:model', 354), ('concept:scientificterm', 342), ('concept:politician', 335), ('concept:musicartist', 333), ('concept:book', 331), ('concept:governmentorganization', 327), ('concept:year', 326), ('concept:agriculturalproduct', 315), ('concept:personnorthamerica', 315), ('concept:amphibian', 314), ('concept:militaryconflict', 314), ('concept:bedroomitem', 313), ('concept:reptile', 311), ('concept:winery', 298), ('concept:street', 297), ('concept:medicalprocedure', 291), ('concept:placeofworship', 288), ('concept:beverage', 279), ('concept:monument', 268), ('concept:astronaut', 265), ('concept:organization', 264), ('concept:academicfield', 263), ('concept:emotion', 257), ('concept:furniture', 253), ('concept:politicsblog', 251), ('concept:retailstore', 251), ('concept:musicsong', 246), ('concept:restaurant', 243), ('concept:language', 241), ('concept:recipe', 237), ('concept:country', 235), ('concept:plant', 233), ('concept:highway', 232), ('concept:shoppingmall', 232), ('concept:musician', 232), ('concept:beach', 227), ('concept:mldataset', 225), ('concept:automobilemaker', 223), ('concept:arachnid', 219), ('concept:visualartist', 218), ('concept:mlauthor', 217), ('concept:consumerelectronicitem', 210), ('concept:race', 206), ('concept:bodypart', 204), ('concept:fish', 203), ('concept:vehicle', 199), ('concept:radiostation', 194), ('concept:blog', 190), ('concept:arthropod', 187), ('concept:recordlabel', 185), ('concept:software', 181), ('concept:island', 180), ('concept:farm', 177), ('concept:criminal', 173), ('concept:charactertrait', 171), ('concept:animal', 170), ('concept:videogame', 168), ('concept:sport', 163), ('concept:building', 155), ( ...
# DONE
# EXECUTION TIME: 16.5969929695 s

# %%
# TOP 10 classes

#[('concept:beach', 34501), ('concept:actor', 29293),
#('concept:governmentorganization', 27738), ('concept:director', 27569),
#('concept:skiarea', 27356), ('concept:street', 25287),
#('concept:river', 23763), ('concept:airport', 23719),
#('concept:celebrity', 23424), ('concept:male', 23277)]

# %%
# class indegree & outdegree

import os
import time
import string
import itertools
import re
import operator

start = time.time()

nellSample = 'NELL/NELL_sample.csv'
nell = 'NELL/NELL.08m.995.esv.csv'
ontology = 'NELL/NELL.08m.995.ontology.csv'

degreeDic = {} #key:entity, value:indegree
seenEntities = set()
topClasses = set()
topClasses.update(['concept:beach','concept:actor','concept:governmentorganization','concept:director','concept:skiarea','concept:street','concept:river','concept:airport', 'concept:celebrity','concept:male'])

def calcDegree(splitted_line):
    word_position = 0
    for word in splitted_line:
#        if (word_position==0): #Entity OUTDEGREE
        if (word_position==2): #Value INDEGREE
            entity = word
            if entity in topClasses:
                #print ('entity in top classes')
                if entity in indegreeDic:
                    degreeDic[entity] += 1
                else:
                    degreeDic[entity] = 1
                    #seenEntities.add(entity)
                    return
            else: #entity not in top classes
                return
        #elif (word_position==1): #Relation
        #    relation = word
        #elif (word_position==2): #Value
        #    value = word
        elif(word_position>2):
            break
        word_position +=1
    #print (entity, relation, value)

    

print('START')
try:
    # read nell & ontology
    for i in xrange(2):
        if (i==0):
            print ('read ontology')
            readFile = ontology
        elif (i==1):
            print ('read NELL')
            readFile = nell
        else:
            print ('ERROR for xrange')
        fn = open(readFile, 'r')
        lineCounter = 0
        for line in fn:
            if (lineCounter != 0):
                splitted_line = line.rstrip('\n').split('\t')
                calcDegree(splitted_line)
            lineCounter += 1
            if (lineCounter % lineProgress == 0):
                print ('{} lines read'.format(lineCounter))
        fn.close()
    print sorted(degreeDic.items(), key=operator.itemgetter(1), reverse=True)
    print ('DONE')
except:
    print('ERROR')

end = time.time()
print ('EXECUTION TIME: {} s'.format(end-start))
# Out:
# START
# read ontology
# 500000 lines read
# read NELL
# 500000 lines read
# 1000000 lines read
# 1500000 lines read
# 2000000 lines read
# 2500000 lines read
# [('concept:beach', 34548), ('concept:actor', 29319), ('concept:governmentorganization', 27742), ('concept:director', 27593), ('concept:skiarea', 27369), ('concept:street', 25352), ('concept:river', 23823), ('concept:airport', 23742), ('concept:celebrity', 23436), ('concept:male', 23291)]
# DONE
# EXECUTION TIME: 14.7542960644 s

# %%
# class instances indegree & outdegree

import os
import time
import string
import itertools
import re
import operator

start = time.time()

nellSample = 'NELL/NELL_sample.csv'
nell = 'NELL/NELL.08m.995.esv.csv'
ontology = 'NELL/NELL.08m.995.ontology.csv'

lineProgress = 1000000

topClasses = set()
topClasses.update(['concept:beach','concept:actor','concept:governmentorganization','concept:director','concept:skiarea','concept:street','concept:river','concept:airport', 'concept:celebrity','concept:male'])
# sets for each class to hold all instances
allInstances = set()
instancesBeach = set()
instancesActor = set()
instancesGovOrg = set()
instancesDirector = set()
instancesSkiArea = set()
instancesStreet = set()
instancesRiver = set()
instancesAirport = set()
instancesCelebrity = set()
instancesMale = set()

class ClassInstances:
    def __init__(self, name):
        self.name = name
        self.allClassInstances = set()
        self.countDict = dict()
        self.min = 9999999
        self.max = 0
        self.avg = 0.0
    def addInstance(self, instance):
        if instance in self.allClassInstances:
            self.countDict[instance] += 1
        else:
            self.countDict[instance] = 1
            self.allClassInstances.add(instance)
    def calculateDegrees(self):
        #print ('calculate degrees within ClassInstances')
        for k,v in self.countDict.iteritems():
            if (v < self.min):
                self.min = v
            if (v > self.max):
                self.max = v
            self.avg += v
        self.avg = self.avg / len(self.countDict)
    def printResults(self):
        print ('{}'.format(self.name))
        print ('min: {}, avg: {}, max: {}'.format(self.min, self.avg, self.max))
        

# instantiation of all class instances for indegree          
beachCi = ClassInstances('class instances indegree for beach')
actorCi = ClassInstances('class instances indegree for actor')
govOrgCi = ClassInstances('class instances indegree for governmentorganization')
directorCi = ClassInstances('class instances indegree for director')
skiAreaCi = ClassInstances('class instances indegree for skiarea')
streetCi = ClassInstances('class instances indegree for street')
riverCi = ClassInstances('class instances indegree for river')
airportCi = ClassInstances('class instances indegree for airport')
celebrityCi = ClassInstances('class instances indegree for celebrity')
maleCi = ClassInstances('class instances indegree for male')
# list with references to all indegree classes
classInstancesIndegree = [beachCi, actorCi, govOrgCi, directorCi, skiAreaCi, streetCi, riverCi, airportCi, celebrityCi, maleCi]

# instantiation of all class instances for outdegree          
beachCo = ClassInstances('class instances outdegree for beach')
actorCo = ClassInstances('class instances outdegree for actor')
govOrgCo = ClassInstances('class instances outdegree for governmentorganization')
directorCo = ClassInstances('class instances outdegree for director')
skiAreaCo = ClassInstances('class instances outdegree for skiarea')
streetCo = ClassInstances('class instances outdegree for street')
riverCo = ClassInstances('class instances outdegree for river')
airportCo = ClassInstances('class instances outdegree for airport')
celebrityCo = ClassInstances('class instances outdegree for celebrity')
maleCo = ClassInstances('class instances outdegree for male')
# list with references to all outdegree classes
classInstancesOutdegree = [beachCo, actorCo, govOrgCo, directorCo, skiAreaCo, streetCo, riverCo, airportCo, celebrityCo, maleCo]
        

#beachL, actorL, govOrgL, directorL, skiAreaL, streetL, riverL, airpotL, celebrityL, maleL = ([] for i in range(10))

#indegrees = {} #key:instanceClass(min,count,max), value: indegree
#outdegrees = {} #key:instanceClass(min,count,max), value: outdegree

def getInstances(splitted_line):
    word_position = 0
    for word in splitted_line:
        if (word_position==0): #Entity 
            entity = word
        elif (word_position==1): #Relation
            relation = word
        elif (word_position==2): #Value
            value = word
            if (relation == 'generalizations' and value in topClasses):
                # check for specific class and add instance to the class set
                if (value == 'concept:beach'):
                    if entity not in instancesBeach:
                        instancesBeach.add(entity)
                    return
                elif (value == 'concept:actor'):
                    if entity not in instancesActor:
                        instancesActor.add(entity)
                    return
                elif (value == 'concept:governmentorganization'):
                    if entity not in instancesGovOrg:
                        instancesGovOrg.add(entity)
                    return
                elif (value == 'concept:director'):
                    if entity not in instancesDirector:
                        instancesDirector.add(entity)
                    return
                elif (value == 'concept:skiarea'):
                    if entity not in instancesSkiArea:
                        instancesSkiArea.add(entity)
                    return
                elif (value == 'concept:street'):
                    if entity not in instancesStreet:
                        instancesStreet.add(entity)
                    return
                elif (value == 'concept:river'):
                    if entity not in instancesRiver:
                        instancesRiver.add(entity)
                    return
                elif (value == 'concept:airport'):
                    if entity not in instancesAirport:
                        instancesAirport.add(entity)
                    return
                elif (value == 'concept:celebrity'):
                    if entity not in instancesCelebrity:
                        instancesCelebrity.add(entity)
                    return
                elif (value == 'concept:male'):
                    if entity not in instancesMale:
                        instancesMale.add(entity)
                    return
                return
            else: # NOT relation == 'generalizations' and value in topClasses
                return                
        elif(word_position>2):
            return
        word_position +=1

def countInstanceDegrees(splitted_line):
    word_position = 0
    for word in splitted_line:
        if (word_position==0): #Entity: OUTDEGREE
            entity = word
            if entity in allInstances:
                if entity in instancesBeach:
                    beachCo.addInstance(entity)
                elif entity in instancesActor:
                    actorCo.addInstance(entity)
                elif entity in instancesGovOrg:
                    govOrgCo.addInstance(entity)
                elif entity in instancesDirector:
                    directorCo.addInstance(entity)
                elif entity in instancesSkiArea:
                    skiAreaCo.addInstance(entity)
                elif entity in instancesStreet:
                    streetCo.addInstance(entity)
                elif entity in instancesRiver:
                    riverCo.addInstance(entity)
                elif entity in instancesAirport:
                    airportCo.addInstance(entity)
                elif entity in instancesCelebrity:
                    celebrityCo.addInstance(entity)
                elif entity in instancesMale:
                    maleCo.addInstance(entity)
        
        elif (word_position==2): #Value: INDEGREE
            value = word
            if value in allInstances:
                if value in instancesBeach:
                    beachCi.addInstance(value)
                elif value in instancesActor:
                    actorCi.addInstance(value)
                elif value in instancesGovOrg:
                    govOrgCi.addInstance(value)
                elif value in instancesDirector:
                    directorCi.addInstance(value)
                elif value in instancesSkiArea:
                    skiAreaCi.addInstance(value)
                elif value in instancesStreet:
                    streetCi.addInstance(value)
                elif value in instancesRiver:
                    riverCi.addInstance(value)
                elif value in instancesAirport:
                    airportCi.addInstance(value)
                elif value in instancesCelebrity:
                    celebrityCi.addInstance(value)
                elif value in instancesMale:
                    maleCi.addInstance(value)                
            return # done processing entity and value
        elif(word_position>2):
            return
        word_position +=1
        
def calculateClassDegrees():
    for item in classInstancesIndegree:
        item.calculateDegrees()
    for item in classInstancesOutdegree:
        item.calculateDegrees()
        
def printClassDegreeResults():
    for item in classInstancesIndegree:
        item.printResults()
    for item in classInstancesOutdegree:
        item.printResults()
    

print('START')
try:
    # get Instances and calculate indegree&outdegree
    for i in xrange(2):
        if (i==0):
            print ('1. run: get class instances')
        elif (i==1):
            print ('2. run: count instance degrees')
        # read nell & ontology
        for j in xrange(2):
            if (j==0):
                print ('read ontology')
                readFile = ontology
            elif (j==1):
                print ('read NELL')
                readFile = nell
            fn = open(readFile, 'r')
            lineCounter = 0
            for line in fn:
                if (lineCounter != 0):
                    splitted_line = line.rstrip('\n').split('\t')
                    if (i==0):
                        getInstances(splitted_line)
                    elif (i==1):
                        countInstanceDegrees(splitted_line)
                    else:
                        calculateClassDegrees(splitted_line)
                lineCounter += 1
                if (lineCounter % lineProgress == 0):
                    print ('{} lines read'.format(lineCounter))
            fn.close()
        if (i==0):
            # create set of all instances
            allInstances = instancesBeach|instancesActor|instancesGovOrg|instancesDirector|instancesSkiArea|instancesStreet|instancesRiver|instancesAirport|instancesCelebrity|instancesMale
    # calculate min, avg, max class degrees
    print ('calculate class degrees')
    calculateClassDegrees()
    print('RESULTS')
    printClassDegreeResults()
    
    #print sorted(indegreeDic.items(), key=operator.itemgetter(1), reverse=True)
    #print('len(instancesBeach): {}'.format(len(instancesBeach)))
    #print('len(instancesActor): {}'.format(len(instancesActor)))
    #print('len(instancesGovOrg): {}'.format(len(instancesGovOrg)))
    #print('len(instancesDirector): {}'.format(len(instancesDirector)))
    #print('len(instancesSkiArea): {}'.format(len(instancesSkiArea)))
    #print('len(instancesStreet): {}'.format(len(instancesStreet)))
    #print('len(instancesRiver): {}'.format(len(instancesRiver)))
    #print('len(instancesAirport): {}'.format(len(instancesAirport)))
    #print('len(instancesCelebrity): {}'.format(len(instancesCelebrity)))
    #print('len(instancesMale): {}'.format(len(instancesMale)))
    #print('len(allInstances): {}'.format(len(allInstances)))
    
    #print('len(beachCi.countDict): {}'.format(len(beachCi.countDict)))
    #print ('beachCi.countDict: {}'.format(beachCi.countDict))
    #print('len(beachCo.countDict): {}'.format(len(beachCo.countDict)))
    #print ('beachCi.min: {}'.format(beachCi.min))
    #print ('beachCi.max: {}'.format(beachCi.max))
    #print ('beachCi.avg: {}'.format(beachCi.avg))
    
    print ('DONE')
except:
    print('ERROR')

end = time.time()
print ('EXECUTION TIME: {} s'.format(end-start))
# Out:
# START
# 1. run: get class instances
# read ontology
# read NELL
# 1000000 lines read
# 2000000 lines read
# 2. run: count instance degrees
# read ontology
# read NELL
# 1000000 lines read
# 2000000 lines read
# calculate class degrees
# len(instancesBeach): 34502
# len(allInstances): 237137
# len(beachCi.countDict): 12
# len(beachCo.countDict): 34502
# beachCi.min: 1
# beachCi.max: 4
# beachCi.avg: 1
# DONE
# EXECUTION TIME: 31.6661360264 s
